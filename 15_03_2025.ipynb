# %%
import google.generativeai as genai
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('apikey')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            text += page.extract_text() + "\n"
    return text

# %%
def extract_health_insights(text):
    """Asks Gemini AI to extract key medical insights from the report."""
    model = genai.GenerativeModel("gemini-1.5-flash")
    prompt = f"Extract key insights from the following health report:\n\n{text}"
    response = model.generate_content(prompt)
    return response.text
pdf_file = "health_report.pdf"
extracted_text = extract_text_from_pdf(pdf_file)
insights = extract_health_insights(extracted_text)
print("key Insights:\n", insights)
# Out:
# key Insights:
#  Mr. Kishan Goud's (MR2100003157, IP2100041193) health report from 01/02/2021 reveals the following:
#
# **Infectious Diseases:**
#
# * **Widal Test:** Elevated titers for *Salmonella Typhi* "O" (1:160) and "H" (1:80) suggest a possible past or present *Salmonella Typhi* infection.  However,  *Salmonella Paratyphi* "A"H and "B"H titers are within the normal range.  Further investigation might be needed to confirm active infection.
# * **Dengue Serology:** Negative for Dengue NS1 antigen, IgG, and IgM antibodies, indicating no current or recent dengue fever infection.
# * **Malaria:** Negative rapid malaria test for *Plasmodium falciparum* and *Plasmodium vivax*, ruling out malaria.
#
# **Hematology:**
#
# * **Complete Blood Picture (CBP):**  All values (Hemoglobin, RBC, WBC, Platelets, PCV, Differential Count) are within normal ranges, except for slightly elevated ESR (26 mm/hr in the first hour, 52 mm/hr in the second). Elevated ESR can indicate inflammation or infection.
# * **HbA1c:** 5.4%, indicating well-controlled blood sugar levels within the normal non-diabetic range.
#
# **Biochemistry:**
#
# * **Liver Function Test (LFT):**  All liver function parameters (bilirubin, alkaline phosphatase, SGOT, SGPT, total protein, albumin, globulin, A/G ratio) are within normal ranges.
# * **Serum Electrolytes:** Serum Sodium (122 mmol/l) is slightly below the normal range (135-146 mmol/l), while Potassium and Chloride are within normal limits.  The low sodium warrants further investigation.
# * **Serum Creatinine:** 0.8 mg/dl, within the normal range (0.6-1.25 mg/dl), indicating normal kidney function.
# * **Random Blood Glucose:** Within the normal range (60-170 mg/dl).
#
#
# **Overall:**
#
# While the elevated Widal test titers and slightly low sodium level require attention, most of the other test results are within normal ranges. The elevated ESR suggests possible underlying inflammation or infection, which should be investigated further in conjunction with the Widal test results and low sodium to determine the cause. The patient's slightly elevated ESR and borderline low sodium warrant further clinical evaluation and potentially additional testing to determine the underlying cause of these findings.  The negative results for dengue and malaria are reassuring.

# %%
def summarize_health_report(text):
  """Summarizes the health rport using Gemini AI."""
  model = genai.GenerativeModel("gemini-1.5-flash")
  prompt = f"Summarize the following health report in a concise manner:\n\n{text}"
  response = model.generate_content(prompt)
  return response.text

summary = summarize_health_report(extracted_text)
print("Summary:\n", summary)
# Out:
# Summary:
#  Mr. Kishan Goud's (MRN: MR2100003157) blood tests on 01/02/2021 revealed:  Elevated ESR (26/52 mm/hr), with Widal test showing borderline positive for *S. Typhi* "O" (1:160) and "H" (1:80).  Dengue serology, malaria test, and HbA1c were negative/normal.  Complete blood count showed normal values except for slightly low platelets (2.0 lakhs/cumm).  Liver function tests, serum electrolytes, and creatinine were mostly within normal ranges, although serum sodium was slightly low (122 mmol/l).  Random blood glucose was within normal limits.

# %%
def detect_abnormalities(text):

  """Analyzes lab text results and flags abnormal values."""
  model = genai.GenerativeModel("gemini-1.5-flash")
  prompt = f"Analyze the lab test results in the following health report and highlight any\nabnormal values:\n\n{text}"
  response = model.generate_content(prompt)
  return response.text


abnormalities = detect_abnormalities(extracted_text)
print("Potential Abnormalities:\n", abnormalities)
# Out:
# Potential Abnormalities:
#  The following lab results from Mr. Kishan Goud's report are outside the provided biological reference ranges, indicating potential abnormalities:
#
# * **Widal Test:**  S. Typhi "O" (1:160) and S. Typhi "H" (1:80) are significantly higher than the reference range of 1:20. This suggests a possible *Salmonella Typhi* infection (typhoid fever).  Further investigation and clinical correlation are necessary for diagnosis.
#
# * **Erythrocyte Sedimentation Rate (ESR):**  Both the 1st-hour (26 mm/hr) and 2nd-hour (52 mm/hr) ESR values are elevated above the normal range (0-8 mm/hr for the first hour).  Elevated ESR indicates inflammation in the body, but it's a non-specific marker and needs to be interpreted alongside other findings.
#
# * **Serum Sodium:** The serum sodium level (122 mmol/l) is below the normal range (135-146 mmol/l), indicating hyponatremia (low sodium in the blood). This requires further evaluation to determine the underlying cause.
#
# * **Serum Chloride:** The serum chloride level (97 mmol/l) is slightly below the lower limit of the normal range (98-107 mmol/l). While it's close to the lower bound, it's worth noting along with the hyponatremia.
#
#
# **Important Note:**  This analysis is based solely on the provided lab values and reference ranges.  A proper medical diagnosis can only be made by a physician considering these results in conjunction with the patient's complete medical history, physical examination, and other relevant clinical information.  The high Widal test titres and low serum sodium particularly warrant further attention.

# %%
def explain_medical_terms(text):

  """Asks Gemini AI to simplify medical terms for patient understanding."""
  model = genai.GenerativeModel("gemini-1.5-flash")
  prompt = f"Explain the medical terms in the following health report in simple language:\n\n{text}"
  response = model.generate_content(prompt)
  return response.text

explaination = explain_medical_terms(extracted_text)
print("Simplified Explaination:\n", abnormalities)
# Out:
# Simplified Explaination:
#  This report shows the results of several blood tests performed on Mr. Kishan Goud. Let's break down each section:
#
#
# **1. WIDAL Test:** This test checks for antibodies against *Salmonella Typhi* and *Salmonella Paratyphi*, bacteria that cause typhoid fever and paratyphoid fever.  The results are expressed as dilutions.  A higher number indicates a stronger immune response (meaning the body is fighting the infection).  In this case:
#
# * **S. Typhi "O" 1:160:**  Suggests a possible past or present infection with *Salmonella Typhi*.  The reference range is 1:20, so this result is significantly higher.
# * **S. Typhi "H" 1:80:** Similar to above, also suggests a possible past or present infection with *Salmonella Typhi*.  Higher than the reference range.
# * **S. Paratyphi "AH" 1:20:** Within the normal range, suggesting no current or recent infection with *Salmonella Paratyphi* AH.
# * **S. Paratyphi "BH" 1:20:**  Within the normal range, suggesting no current or recent infection with *Salmonella Paratyphi* BH.
#
# **2. Dengue Serology:** This test checks for dengue fever. The results are all negative, meaning no evidence of dengue infection was found.  NS1, IgG, and IgM are different types of antibodies or antigens related to dengue.
#
# * **Dengue NS1 Antigen:** Negative
# * **Dengue IgG:** Negative
# * **Dengue IgM:** Negative
#
#
# **3. Erythrocyte Sedimentation Rate (ESR):** This test measures how quickly red blood cells settle in a tube of blood. A higher ESR can indicate inflammation or infection in the body.
#
# * **ESR 1st Hour 26 mm/hr:** Elevated (above the normal range of 0-8 mm/hr).
# * **ESR 2nd Hour 52 mm/hr:**  Further elevated.  This suggests inflammation is present.
#
#
# **4. Rapid Malaria Test:** This is a quick test to detect malaria parasites in the blood. Both tests are negative, meaning no malaria parasites were found.
#
# * **Rapid Malaria Test P.V:** Negative (Plasmodium vivax)
# * **Rapid Malaria Test P.F:** Negative (Plasmodium falciparum)
#
#
# **5. Complete Blood Picture (CBC):** This is a comprehensive blood test that provides information about different components of the blood.
#
# * **Hemoglobin (Hb):** 13.6 gms% (within the normal range of 13-17).  Measures the oxygen-carrying capacity of the blood.
# * **Red Blood Cells (RBC):** 4.3 mill/cumm (slightly below the normal range of 4.5-5.5).
# * **White Blood Cells (WBC):** 7,200 cells/cumm (within the normal range of 4000-10000).  These fight infection.
# * **Platelet Count:** 2.0 lakhs/cumm (within the normal range of 1.5-4.5).  Important for blood clotting.
# * **Packed Cell Volume (PCV):** 40.5% (within the normal range of 40-50).  The percentage of red blood cells in the blood.
# * **Differential Count:** This shows the percentages of different types of white blood cells. All are within or near the normal ranges.
# * **Peripheral Blood Smear:** A microscopic examination of the blood; this result indicates normal findings.
#
#
# **6. HbA1c:** This test measures average blood glucose levels over the past 2-3 months.  It's used to monitor diabetes.
#
# * **HbA1c 5.4%:** This indicates good blood sugar control and is within the normal non-diabetic range (4-6%).
#
#
# **7. Serum Creatinine:** This test measures creatinine levels in the blood, an indicator of kidney function.
#
# * **Serum Creatinine 0.8 mg/dl:** This is within the normal range (0.6-1.25 mg/dl).
#
#
# **8. Random Blood Glucose:** This measures blood glucose at a random time.
#
# * **Random Blood Glucose:** The result is missing from your provided text.
#
#
# **9. Liver Function Test (LFT):**  A series of tests that assess liver health.  All results are within or close to the normal range.
#
# * **Serum Bilirubin (Total, Direct, Indirect):** All within normal ranges, indicating normal liver function concerning bilirubin processing.
# * **Serum Alkaline Phosphatase:** Within normal range.
# * **SGOT (AST):**  Within normal range.  (Also called aspartate aminotransferase)
# * **SGPT (ALT):** Within normal range.  (Also called alanine aminotransferase)
# * **Total Protein & Albumin:** Within normal ranges.
# * **Globulin:** Result provided.
# * **A/G Ratio:** Albumin/Globulin ratio; result provided, within normal range.
#
#
# **10. Serum Electrolytes:** These tests measure the levels of essential minerals in the blood.
#
# * **Serum Sodium:** Slightly low (122 mmol/l, compared to the normal range of 135-146 mmol/l).
# * **Serum Potassium:** Within the normal range (3.5 mmol/l).
# * **Serum Chloride:** Slightly low (97 mmol/l, compared to the normal range of 98-107 mmol/l).
#
#
# **Overall Interpretation:**
#
# The results show some abnormalities that require further investigation by a doctor. The elevated ESR suggests inflammation, while the slightly low sodium and chloride levels might indicate a dehydration or other underlying issues. The Widal test results suggest past or present *Salmonella Typhi* infection which requires further clarification by the physician.  The doctor should interpret these results in the context of Mr. Kishan Goud's clinical presentation and symptoms.  This information should not be used for self-diagnosis or treatment.

# %%
def ask_gemini_about_report(text, question):

  """Allows users to ask questions about their health report."""
  model = genai.GenerativeModel("gemini-1.5-flash")
  prompt = f"The following is a health report:\n\n{text}\n\nAnswer the following question based on the report:\n{question}"
  response = model.generate_content(prompt)
  return response.text

question = "What is the patient's diagnosis?"
answer = ask_gemini_about_report(extracted_text, question)
print("Answer:\n", answer)
# Out:
# Answer:
#  The provided lab report does not offer a diagnosis.  It presents various test results, some of which show values outside the normal range (e.g., elevated ESR). However, these results alone are insufficient to establish a diagnosis.  A physician must interpret these results in conjunction with the patient's symptoms, medical history, and a physical examination to determine a diagnosis.
