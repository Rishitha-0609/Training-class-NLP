# %% [markdown]
# ### Extracting Data from File

# %%
### Collecting data from word file

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/3e/3d/330d9efbdb816d3f60bf2ad92f05e1708e4a1b9abe80461ac3444c83f749/python_docx-1.1.2-py3-none-any.whl.metadata
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\anaconda3\lib\site-packages (from python-docx) (4.9.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    ---------------------------------------- 244.3/244.3 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2

# %%
import docx

# %%
doc = open("Literature survey BT-12 (1).docx","rb")
document = docx.Document(doc)

# %%
docu=""
for para in document.paragraphs:
    docu += para.text
print(docu)
# Out:
# III Year B.Tech. -II SemesterName of Examination: Application Development- - Web Application with Natural Language Processing & IOT ExploreCourse Code: MR22-1CS0264 Section: BETA (BT-12)Literature SurveyFOOD PRODUCT ANALYZER USING NATURAL LANGUAGE PROCESSING(NLP)Introduction to Food Product Analysis :Food product analysis has gained significant importance due to the increasing consumer interest in health-conscious eating, food transparency, and dietary preferences. With the rapid growth in food products and ingredients, traditional methods of analysis are time-consuming, expensive, and prone to human error. This has prompted the development of innovative methods, including Natural Language Processing (NLP), to automate the analysis of food products' ingredients, nutritional values, allergens, and claims.Role of NLP in Food Product AnalysisNatural Language Processing (NLP), a subfield of artificial intelligence (AI), enables machines to process and interpret human language. NLP has become an essential tool in understanding and extracting useful information from vast amounts of unstructured data such as food labels, ingredient lists, customer reviews, and nutrition databases. NLP methods can be used to:Extract relevant information from food packaging textAnalyze nutritional values and allergen warningsIdentify food trends and consumer preferencesClassify food products based on health benefits or risksTechniques Used in NLP for Food Product AnalysisSeveral NLP techniques are employed in food product analysis. These include:Text Classification: NLP models categorize food product descriptions into predefined classes such as low-fat, vegan, gluten-free, organic, etc.Named Entity Recognition (NER): NER helps in extracting specific information such as ingredients, nutrients, allergens, and additives from textual content.Sentiment Analysis: Consumer reviews or social media discussions can be analyzed to understand sentiments related to food products, their ingredients, or dietary benefits.Information Extraction (IE): This technique helps in identifying and structuring data like product specifications, health claims, and nutritional content.Applications of NLP in Food Product Analysis :NLP techniques are applied in various domains of food product analysis:Food Label Analysis: NLP models analyze the text on food packaging to extract key details such as ingredients, nutritional facts, and allergens, ensuring compliance with regulations.Nutrition & Diet Planning: NLP tools can help consumers make informed decisions by analyzing the nutritional content of food products and matching them with dietary goals or health conditions.Food Recommendation Systems: By analyzing product reviews and descriptions, NLP algorithms can recommend food products based on consumer preferences, dietary restrictions, or trending ingredients.Market Research: NLP is used to mine food-related content from online sources, including blogs, forums, and social media, to identify consumer opinions, market trends, and emerging food products.Challenges and Limitations :While NLP has proven useful in food product analysis, there are several challenges:Data Quality: Food product information can be inconsistent or incomplete across different sources, creating challenges for NLP systems to extract accurate data.Ambiguity in Language: Food labels often use ambiguous language or non-standardized terms, which can make it difficult for NLP models to interpret the data correctly.Multilingual Support: Since food products are sold globally, an NLP-based food product analyzer must support multiple languages, which adds complexity to the system.Domain-Specific Models: A major challenge is building NLP models that are domain-specific to food products and nutrition, as generic NLP models may not always capture the nuances of food- related content.Existing Systems and Tools:Several systems and tools already employ NLP for food product analysis:Yuka: A mobile application that uses NLP to a ...

# %%
for i in range(len(document.paragraphs)):
    print("The content of the paragraph "+ str(i)+" is : " + document.paragraphs[i].text+"\n")
# Out:
# The content of the paragraph 0 is :
#
# The content of the paragraph 1 is :
#
# The content of the paragraph 2 is : III Year B.Tech. -II Semester
#
# The content of the paragraph 3 is :
#
# The content of the paragraph 4 is : Name of Examination: Application Development- - Web Application with Natural Language Processing & IOT Explore
#
# The content of the paragraph 5 is :
#
# The content of the paragraph 6 is : Course Code: MR22-1CS0264 Section: BETA (BT-12)
#
# The content of the paragraph 7 is :
#
# The content of the paragraph 8 is :
#
# The content of the paragraph 9 is : Literature Survey
#
# The content of the paragraph 10 is : FOOD PRODUCT ANALYZER USING NATURAL LANGUAGE PROCESSING(NLP)
#
# The content of the paragraph 11 is :
#
# The content of the paragraph 12 is : Introduction to Food Product Analysis :
#
# The content of the paragraph 13 is :
#
# The content of the paragraph 14 is : Food product analysis has gained significant importance due to the increasing consumer interest in health-conscious eating, food transparency, and dietary preferences. With the rapid growth in food products and ingredients, traditional methods of analysis are time-consuming, expensive, and prone to human error. This has prompted the development of innovative methods, including Natural Language Processing (NLP), to automate the analysis of food products' ingredients, nutritional values, allergens, and claims.
#
# The content of the paragraph 15 is :
#
# The content of the paragraph 16 is : Role of NLP in Food Product Analysis
#
# The content of the paragraph 17 is :
#
# The content of the paragraph 18 is : Natural Language Processing (NLP), a subfield of artificial intelligence (AI), enables machines to process and interpret human language. NLP has become an essential tool in understanding and extracting useful information from vast amounts of unstructured data such as food labels, ingredient lists, customer reviews, and nutrition databases. NLP methods can be used to:
#
# The content of the paragraph 19 is :
#
# The content of the paragraph 20 is : Extract relevant information from food packaging text
#
# The content of the paragraph 21 is :
#
# The content of the paragraph 22 is : Analyze nutritional values and allergen warnings
#
# The content of the paragraph 23 is :
#
# The content of the paragraph 24 is : Identify food trends and consumer preferences
#
# The content of the paragraph 25 is :
#
# The content of the paragraph 26 is : Classify food products based on health benefits or risks
#
# The content of the paragraph 27 is :
#
# The content of the paragraph 28 is :
#
# The content of the paragraph 29 is :
#
# The content of the paragraph 30 is : Techniques Used in NLP for Food Product Analysis
#
# The content of the paragraph 31 is :
#
# The content of the paragraph 32 is : Several NLP techniques are employed in food product analysis. These include:
#
# The content of the paragraph 33 is :
#
# The content of the paragraph 34 is : Text Classification: NLP models categorize food product descriptions into predefined classes such as low-fat, vegan, gluten-free, organic, etc.
#
# The content of the paragraph 35 is :
#
# The content of the paragraph 36 is : Named Entity Recognition (NER): NER helps in extracting specific information such as ingredients, nutrients, allergens, and additives from textual content.
#
# The content of the paragraph 37 is :
#
# The content of the paragraph 38 is : Sentiment Analysis: Consumer reviews or social media discussions can be analyzed to understand sentiments related to food products, their ingredients, or dietary benefits.
#
# The content of the paragraph 39 is :
#
# The content of the paragraph 40 is : Information Extraction (IE): This technique helps in identifying and structuring data like product specifications, health claims, and nutritional content.
#
# The content of the paragraph 41 is :
#
# The content of the paragraph 42 is :
#
# The content of the paragraph 43 is :
#
# The content of the paragraph 44 is : Applications of NLP in Food Product Analysis :
#
# The content of the paragraph 45 is :
#
# The content of the paragraph 46 is : NLP techniques are applied in various domains of food product analysis:
#
# The content of the paragraph 47 is :
#
# The content of the paragraph 48 is : Food Label Analysis: NLP models analyze the text on food packaging to extract key details such as ingredients, nutritional facts, and allergens, ensuring compliance with regulations.
#
# The content of the paragraph 49 is :
#
# The content of the paragraph 50 is : Nutrition & Diet Planning: NLP tools can help consumers make informed decisions by analyzing the nutritional content of food products and matching them with dietary goals or health conditions.
#
# The content of the paragraph 51 is :
#
# The content of the paragraph 52 is : Food Recommendation Systems: By analyzing product reviews and descriptions, NLP algorithms can recommend food products based on consumer preferences, dietary restrictions, or trending ingredients.
#
# The content of the paragraph 53 is :
#
# The content of the paragraph 54 is : Market Research: NLP is used to mine food-related content from online sources, including blogs, forums, and social media, to identify consumer opinions, market trends, and emerging food products.
#
# The content of the paragraph 55 is :
#
# The content of the paragraph 56 is :
#
# The content of the paragraph 57 is :
#
# The content of the paragraph 58 is : Challenges and Limitations :
#
# The content of the paragraph 59 is :
#
# The content of the paragraph 60 is : While NLP has proven useful in food product analysis, there are several challenges:
#
# The content of the paragraph 61 is :
#
# The content of the paragraph 62 is : Data Quality: Food product information can be inconsistent or incomplete across different sources, creating challenges for NLP systems to extract accurate data.
#
# The content of the paragraph 63 is :
#
# The content of the paragraph 64 is : Ambiguity in Language: Food labels often use ambiguous language or non-standardized terms, which can make it difficult for NLP models to interpret the data correctly.
#
# The content of the paragraph 65 is :
#
# The content of the paragraph 66 is : Multilingual Support: Since food products are sold globally, an NLP-based food product analyzer must support multiple languages, which adds complexity to the system.
#
# The content of the paragraph 67 is :
#
# The content of the paragraph 68 is : Domain-Specific Models: A major challenge is building NLP models that are domain-specific to food products and nutrition, as generic NLP models may not always capture the nuances of food- related content.
#
# The content of the paragraph 69 is :
#
# The content of the paragraph 70 is : Existing Systems and Tools:
#
# The content of the paragraph 71 is :
#
# The content of the paragraph 72 is : Several systems and tools already employ NLP for food product analysis:
#
# The content of the paragraph 73 is :
#
# The content of the paragraph 74 is : Yuka: A mobile application that uses NLP to analyze food labels, providing health scores based on the ingredients and nutritional content.
#
# The content of the paragraph 75 is :
#
# The content of the paragraph 76 is : Open Food Facts: A global food database where users can find detailed information about food products using barcode scanning and NLP techniques.
#
# The content of the paragraph 77 is :
#
# The content of the paragraph 78 is : FoodData Central by USDA: A comprehensive food database that can be leveraged by NLP models for extracting detailed nutritional information.
#
# The content of the paragraph 79 is :
#
# The content of the paragraph 80 is : AI-based Recipe Analyzers: Platforms like IBM Watson’s Recipe Analyzer use NLP to break down ingredients and nutritional content from recipes.
#
# The content of the paragraph 81 is :
#
# The content of the paragraph 82 is :
#
# The content of the paragraph 83 is :
#
# The content of the paragraph 84 is : Future Directions :
#
# The content of the paragraph 85 is :
#
# The content of the paragraph 86 is : NLP Techniques:
#
# The content of the paragraph 87 is :
#
# The content of the paragraph 88 is : Text Preprocessing:
#
# The content of the paragraph 89 is :
#
# The content of the paragraph 90 is : Tokenization, stemming, lemmatization, and stop-word removal to clean user input.
#
# The content of the paragraph 91 is :
#
# The content of the paragraph 92 is : Named Entity Recognition (NER):
#
# The content of the paragraph 93 is :
#
# The content of the paragraph 94 is : Extract entities like food names, brands, ingredients, allergens, or nutritional components.
#
# The content of the paragraph 95 is :
#
# The content of the paragraph 96 is : Sentiment Analysis:
#
# The content of the paragraph 97 is :
#
# The content of the paragraph 98 is : Analyze user reviews or feedback on food products for positive, negative, or neutral sentiment.
#
# The content of the paragraph 99 is :
#
# The content of the paragraph 100 is : Text Classification:
#
# The content of the paragraph 101 is :
#
# The content of the paragraph 102 is : Categorize food products based on type (e.g., vegan, gluten-free, organic).
#
# The content of the paragraph 103 is :
#
# The content of the paragraph 104 is : Information Retrieval:
#
# The content of the paragraph 105 is :
#
# The content of the paragraph 106 is : Implement search features for users to find food products by keywords or phrases.
#
# The content of the paragraph 107 is :
#
# The content of the paragraph 108 is : Conclusion
#
# The content of the paragraph 109 is :
#
# The content of the paragraph 110 is : The application of Natural Language Processing in food product analysis is revolutionizing the way we interact with food labels, nutritional information, and consumer feedback. By automating the extraction and interpretation of food-related data, NLP enhances transparency, enables personalized health recommendations, and fosters informed decision-making in food consumption. However, for it to be widely adopted, advancements in data quality, language ambiguity resolution, and system accuracy will need to be addressed.
#
# The content of the paragraph 111 is :
#
# The content of the paragraph 112 is :
#
# The content of the paragraph 113 is :
#
# The content of the paragraph 114 is : ---
#
# The content of the paragraph 115 is :
#
# The content of the paragraph 116 is :
#
# The content of the paragraph 117 is :
#
# The content of the paragraph 118 is : References :
#
# The content of the paragraph 119 is :
#
# The content of the paragraph 120 is : Aghaei, S., & Ranjbari, M. (2020).
#
# The content of the paragraph 121 is :
#
# The content of the paragraph 122 is : "Application of Natural Language Processing for the Analysis of Food Product Labels and Ingredients." Journal of Food Science and Technology, 57(5), 1633-1643.This paper discusses NLP techniques applied to food product labels, focusing on the extraction of nutritional data and allergens.
#
# The content of the paragraph 123 is :
#
# The content of the paragraph 124 is : Zhang, X., Yang, Y., & Wang, Y. (2021).
#
# The content of the paragraph 125 is :
#
# The content of the paragraph 126 is : "Natural Language Processing-Based Food Recommendation System Using Nutritional and Ingredient Information." IEEE Access, 9, 18465-18474.This study examines the use of NLP in building food recommendation systems that analyze ingredients and nutritional content.
#
# The content of the paragraph 127 is :
#
# The content of the paragraph 128 is : Miller, R., & Brown, P. (2019).
#
# The content of the paragraph 129 is :
#
# The content of the paragraph 130 is : "AI and NLP in Food Labeling: Trends, Challenges, and Opportunities." Food Quality and Preference, 73, 75-88.DOI: 10.1016/j.foodqual.2018.11.012.An overview of NLP in food labeling, including challenges with data inconsistency and ambiguity in language.
#
# The content of the paragraph 131 is :
#
# The content of the paragraph 132 is : Xu, X., & Zhang, L. (2020):
#
# The content of the paragraph 133 is :
#
# The content of the paragraph 134 is : "Use of Machine Learning and NLP to Classify Food Products Based on Ingredients and Nutritional Information." Journal of Nutritional Science and Vitaminology, 66(3), 275-281.DOI: 10.3177/jns.66.275.This paper discusses how machine learning, combined with NLP, can classify food products according to their ingredients and nutritional data.
#
# The content of the paragraph 135 is :
#
# The content of the paragraph 136 is :
#
# The content of the paragraph 137 is :
#
# The content of the paragraph 138 is :
#
# The content of the paragraph 139 is : Guo, Y., & Shi, L. (2021).
#
# The content of the paragraph 140 is :
#
# The content of the paragraph 141 is : "Sentiment Analysis on Consumer Reviews of Food Products Using Natural Language Processing." International Journal of Food Science & Technology, 56(8), 4012-4022.Explores sentiment analysis techniques applied to consumer reviews for understanding consumer preferences regarding food products.
#
# The content of the paragraph 142 is :
#
# The content of the paragraph 143 is : Esteban, C., & Pérez, J. (2022).
#
# The content of the paragraph 144 is :
#
# The content of the paragraph 145 is : "Food Product Database and NLP for Nutritional Analysis and Health Impact Prediction." Food Research International, 151, 110753.DOI: 10.1016/j.foodres.2021.110753.The study delves into using NLP to process large-scale food product databases for predicting health impacts based on ingredients.
#
# The content of the paragraph 146 is :
#
# The content of the paragraph 147 is : Ghosal, A., & Pal, S. (2020).
#
# The content of the paragraph 148 is :
#
# The content of the paragraph 149 is : "Natural Language Processing in the Development of a Real-Time Food Analyzer." Computers in Biology and Medicine, 124, 103964.DOI: 10.1016/j.compbiomed.2020.103964.This paper discusses the design and implementation of a real-time food analyzer powered by NLP, focusing on ingredient recognition and nutritional analysis.
#
# The content of the paragraph 150 is :
#
# The content of the paragraph 151 is : Le, H. B., & Nguyen, T. T. (2019).
#
# The content of the paragraph 152 is :
#
# The content of the paragraph 153 is : "Data Mining and Natural Language Processing for Personalized Food Recommendation Systems." Computational Biology and Chemistry, 79,Focuses on personalized food recommendation systems that leverage NLP and data mining techniques for analyzing food ingredients and nutritional information.
#
# The content of the paragraph 154 is :
#
# The content of the paragraph 155 is :
#
# The content of the paragraph 156 is :
#
# The content of the paragraph 157 is :
#
# The content of the paragraph 158 is : Nguyen, D., & Lin, W. (2020).
#
# The content of the paragraph 159 is :
#
# The content of the paragraph 160 is :
#
# The content of the paragraph 161 is :
#
# The content of the paragraph 162 is :
#
# The content of the paragraph 163 is : "Text Mining and NLP for Ingredient-based Food Product Categorization." Food Control, 118, 107376.This paper examines text mining and NLP methods for categorizing food products based on their ingredients, offering potential for automated food classification.
#
# The content of the paragraph 164 is :
#
# The content of the paragraph 165 is : Malek, A., & Li, F. (2021).
#
# The content of the paragraph 166 is :
#
# The content of the paragraph 167 is : "Deep Learning for Natural Language Processing in the Analysis of Food Labels and Allergens." Journal of Food Science, 86(5), 2100-2112.This research investigates how deep learning algorithms combined with NLP can be used to identify allergens and other key information from food product labels. advanced studies in emotion recognition.

# %% [markdown]
# ### Collecting Data From HTML

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)

# %%
import urllib.request as urllib2
from bs4 import BeautifulSoup

# %%
response = urllib2.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing')
html_doc = response.read()

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
strhtm = soup.prettify()
print(strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Natural language processing - Wikipedia
#   </title>
#   <script>
#    (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",
# "wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bb8cccbb-931f-4281-aaf8-3aff8c9effb8","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Natural_language_processing","wgTitle":"Natural language processing","wgCurRevisionId":1274942014,"wgRevisionId":1274942014,"wgArticleId":21652,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All accuracy disputes","Accuracy disputes from December 2013","Harv and Sfn no-target errors","CS1 errors: periodical ignored","CS1 maint: location","Articles with short description","Short description is different from Wikidata","Articles needing additional references from May 2024","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from May 2024","Commons category link from Wikidata",
# "Natural language processing","Computational fields of study","Computational linguistics","Speech recognition"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Natural_language_processing","wgRelevantArticleId":21652,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,
# "wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q30642","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.math.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site",
# "mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visu
