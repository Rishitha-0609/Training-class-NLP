# %% [markdown]
# Gemini_AI_Image_Analysis

# %%
import PIL.Image
img=PIL.Image.open('/content/Image 1.jpg')
img
model=genai.GenerativeModel('gemini-1.5-flash')
response=model.generate_content(["Write a short,engaging blog post based on this picture.\nIt should include a description of the meal in the photo and talk about my journey meal prepping.", img],
stream=True)
response.resolve()

# %%
import pathlib
import textwrap
from IPython.display import Markdown, display
def to_markdown(text):
  text=text.replace('.','*')
  return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
to_markdown(response.text)
# Out:
# > ## From Chaos to Calm: My Meal Prep Journey
# >
# > Look at these beauties!  Two perfectly portioned containers, brimming with a vibrant teriyaki chicken and broccoli stir-fry served over fluffy white rice*  Sweet and savory carrots add a pop of color and extra flavor* This isn't just a meal; it's a testament to my newfound love for meal prepping*
# >
# > For years, lunch was a frantic scramble – unhealthy takeout or a sad desk salad* Dinner was even worse, often ending in a messy, last-minute decision*  Then, I decided enough was enough!  I embarked on a meal prep journey, initially feeling overwhelmed by the idea of spending a whole Sunday cooking* But, trust me, it's been worth it*
# >
# > My first attempts were… ambitious*  Too many recipes, too much food, and half of it ended up in the trash* But I persevered, learning from my mistakes* I started small, focusing on one or two simple recipes that I could easily multiply*  Now, I can whip up a week's worth of healthy, delicious meals in a fraction of the time*
# >
# > The benefits have been incredible*  I'm eating healthier, saving tons of money, and most importantly, I'm reducing my daily stress*  No more panicked lunch rushes or rushed dinner choices!  These tasty containers are my little pockets of calm in a busy week*  And let's be honest, they look pretty darn good too!
# >
# > Want to join the meal prep revolution? Share your tips and tricks in the comments below!

# %%
from google.colab import userdata
import google.generativeai as genai

GOOGLE_API_KEY = userdata.get('apikey')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
response = model.generate_content(["Generate an accurate caption for this image.", img])
print(response.text)
# Out:
# Here are a few caption options for the image:
#
# **Option 1 (Simple & Descriptive):**
#
# > Healthy and delicious meal prep!  Chicken and broccoli with rice.
#
# **Option 2 (More Engaging):**
#
# > Lunch goals!  These chicken and veggie bowls are packed with flavor and ready to go.  Perfect for busy days. #mealprep #healthyfood #chickendinner #lunchideas
#
# **Option 3 (Focus on Ease):**
#
# > Easy weeknight dinners made simple with this delicious chicken and vegetable meal prep.  Just grab and go!
#
# **Option 4 (Question to Encourage Engagement):**
#
# > What's your favorite meal prep recipe?  These chicken and broccoli bowls are definitely a contender! #mealprepsunday #healthyrecipes #easymeals
#
#
# The best option will depend on where you plan to use the caption (e.g., Instagram, blog, website).  Option 2 and 4 are best suited for social media platforms.

# %%
from PIL import Image
image_path = "/content/Image 1.jpg"
image = Image.open(image_path)
response = model.generate_content(["Describe this image in detail", image])
print(response.text)
# Out:
# Here's a description of the image:
#
# High-angle, close-up view of two clear glass food containers filled with what appears to be a similar meal.
#
#
# The containers are rectangular and slightly shallower than they are wide. Each container holds a portion of white rice as a base, topped with pieces of cooked chicken or a similar protein.  Bright orange-red diced carrots and vibrant green broccoli florets are also included in each meal, arranged somewhat attractively. The food looks appetizing and is likely a stir-fry or similar dish.
#
#
# The containers are sitting on a mottled light grey surface, possibly a countertop.  A pair of chopsticks with a blue and white patterned design rests partially in the frame, near the lower left corner of the image. In the upper left background, a small, partially visible white bowl and a dark-colored bottle or jar are barely discernible. The overall lighting is bright and even, enhancing the colors of the food.  The scene suggests a healthy, pre-portioned meal prepared for convenience or meal prepping.

# %%
response = model.generate_content(["What emotions can you detect in this image?", image])
print(response.text)
# Out:
# The image evokes feelings of:
#
# * **Happiness/Contentment:** The bright colors and appetizing presentation of the food suggest a feeling of satisfaction and pleasure.  The neatness of the meal prep implies organization and a sense of accomplishment.
# * **Health Consciousness:** The healthy ingredients (broccoli, carrots, chicken, rice) suggest a focus on well-being and a mindful approach to eating.
# * **Preparedness/Organization:** The food is neatly portioned in containers, indicating planning and readiness for a meal, which can be linked to feelings of control and calm.
#
# There are no negative emotions directly conveyed by the image.
