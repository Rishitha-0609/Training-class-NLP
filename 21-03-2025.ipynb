# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\anaconda3\lib\site-packages (1.24.28)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\anaconda3\lib\site-packages (from boto3) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\anaconda3\lib\site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\anaconda3\lib\site-packages (from boto3) (0.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3) (1.26.16)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.28->boto3) (1.16.0)

# %%
# !pip install aswcli
# Out:
# ERROR: Could not find a version that satisfies the requirement aswcli (from versions: none)
# ERROR: No matching distribution found for aswcli

# %%
###

# %%
import boto3
s3 = boto3.client("s3")

# %%
import boto3
s3 = boto3.client("s3")

# %% [markdown]
# ### Create an s3 Bucket

# %%
bucket_name = "mynlpmru6"
s3.create_bucket(
    Bucket=bucket_name,
    CreateBucketConfiguartion={"LocationConstraint": "en-north-1"}
)
print(f"Bucket '{bucket_name}' created successfully!")

# %%
response = s3.list_buckets()
print("Existing Buckets:")
for bucket in reponse["Buckets"]:
    print(f"- {bucket['Name']}")

# %%
s3.upload_file("text.tct", "mynlpmru", "data/testfile1.txt")
print("Upload completed!")

# %%
s3.upload_file("mynlpmru", "data/testfile1.txt", "download_test3.txt")
print("Download completed!")

# %%
response = s3.list_objects_v2(Bucket="mynlpmru2003")
print("File in bucket:")
if "contents" in response:
    for obj in response["Contents"]:
        print(f"-{obj['key']}(Size:{obj['Size']}bytes)")
        else:
            print("Bucket is empty")

# %%
s3.delete_object(Bucket="mynlpmru",Key="data/testfile1.txt")
print("File deleted successfully!")

# %%
s3.put_bucket_versioning(
    Bucket="mynlpmru",
    VersioningConfiguration={"Status":"Enabled"}
    )
print("Bucket versioning enabled")

# %%
copy_source={"Bucket":"mynlpmru","key":"data/testfile.txt"}
s3.copy_object(CopySource=copy_source,Bucket="mynlpmru",key="data/copied_testfile3.txt")
print("file copied successfully")
